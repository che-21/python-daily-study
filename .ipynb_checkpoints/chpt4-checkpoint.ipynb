# %%
def add(a, b):
    return a+b

a = 3
b = 4
c = add(a, b)
print(c)
# Out:
# 7

# %%
def sub(a, b):
	return a-b
	
# 매개변수 지정 (a에 7, b에 3 전달)
result = sub(a=7, b=3)
print(result)
# Out:
# 4

# %%
def sub(a, b):
	return a-b

# 매개변수는 순서에 상관없이 사용 가능
result = sub(b=5, a=3)
print(result)
# Out:
# -2
